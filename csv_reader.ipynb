# %%
with open(r'c:\Users\jediguy\OneDrive\Documents\GitHub\concateDFtoCSV\FrameRecentSessions.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        if line_count == 0:
            print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            print(f'\t{row[0]} works in the {row[1]} department, and was born in {row[2]}.')
            line_count += 1
    print(f'Processed {line_count} lines.')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-b5eae7cf6861> in <module>
# ----> 1 with open(r'c:\Users\jediguy\OneDrive\Documents\GitHub\concateDFtoCSV\FrameRecentSessions.csv') as csv_file:
#       2     csv_reader = csv.reader(csv_file, delimiter=',')
#       3     line_count = 0
#       4     for row in csv_reader:
#       5         if line_count == 0:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'c:\\Users\\jediguy\\OneDrive\\Documents\\GitHub\\concateDFtoCSV\\FrameRecentSessions.csv'
