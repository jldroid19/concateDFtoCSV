# %%
import csv

text = 'Test'

# test = List of strings to be written to file
with open('linebyline.csv', 'wb') as file:
    for line in text:
        file.write(line)
        file.write('\n')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-b69d7ecc4e21> in <module>
#       6 with open('linebyline.csv', 'wb') as file:
#       7     for line in text:
# ----> 8         file.write(line)
#       9         file.write('\n')
#
# TypeError: a bytes-like object is required, not 'str'
