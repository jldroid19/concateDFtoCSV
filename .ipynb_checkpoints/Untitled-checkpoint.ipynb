# %%
import csv
import pandas as pd

warehouse = int(input("Enter Warehouse building number: "))
startbay = int(input("Enter Bay start number: "))
endbay = int(input("Enter Bay end number: "))

data = {'Warehouse': [warehouse],
        'Bay Start': [startbay],
        'Bay End': [endbay]}

for bay in range(startbay, endbay):
    print(bay)

# df['Location No'] = df['Warehouse'].map(str) + '-' + df['Bay Start'].map(str)
    
with open('location_load.csv', 'wb') as csvfile:
    filewriter = csv.writer(csvfile, delimiter=',',
                            quotechar='|', quoting=csv.QUOTE_MINIMAL)
    filewriter.writerow(['Location No','Bay'])
    filewriter.writerow(['',startbay])
# Out:
# Enter Warehouse building number:  381
# Enter Bay start number:  1
# Enter Bay end number:  10
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-836281005c5e> in <module>
#      18     filewriter = csv.writer(csvfile, delimiter=',',
#      19                             quotechar='|', quoting=csv.QUOTE_MINIMAL)
# ---> 20     filewriter.writerow(['Location No','Bay'])
#      21     filewriter.writerow(['',startbay])
#
# TypeError: a bytes-like object is required, not 'str'

# %%
import pandas as pd

warehouse = int(input("Enter Warehouse building number: "))
startbay = int(input("Enter Bay start number: "))
endbay = int(input("Enter Bay end number: "))

data = {'Warehouse': [warehouse],
        'Bay Start': [startbay],
        'Bay End': [endbay]}

df = pd.DataFrame(data, columns=['Warehouse','Bay Start','Bay End'])
print(df)
# Out:
# Enter Warehouse building number:  381
# Enter Bay start number:  32
# Enter Bay end number:  100
#    Warehouse  Bay Start  Bay End
# 0        381         32      100

# %%
df['Location No'] = df['Warehouse'].map(str) + '-' + df['Bay Start'].map(str) + '-' + df['Bay End'].map(str)
print(df)
# Out:
#    Warehouse  Bay Start  Bay End Location No
# 0        381         32      100  381-32-100

# %%
for bay in range(startbay, endbay):
    print(bay)

# for i in range(1, 10):
#     print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
import csv

locate = df['Location No'] = df['Warehouse'].map(str) + '-' + df['Bay Start'].map(str) + '-' + df['Bay End'].map(str)
print(locate)

row_list =[["Location No", "Bay No"],
            [locate, bay]
          ]

with open('location_load.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerows(row_list)
# Out:
# 0    381-32-100
# dtype: object

# %%
locate = df['Warehouse'].map(str) + '-' + df['Bay Start'].map(str) + '-' + df['Bay End'].map(str)
print(locate)
# Out:
# 0    381-32-100
# dtype: object

# %%
location = warehouse.map(str) + '-' + startbay.map(str) + '-' + endbay.map(str)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-713d3582ef2d> in <module>
# ----> 1 location = warehouse.map(str) + '-' + startbay.map(str) + '-' + endbay.map(str)
#
# AttributeError: 'int' object has no attribute 'map'
